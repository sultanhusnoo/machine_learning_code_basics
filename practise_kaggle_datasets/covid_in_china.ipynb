# %%
import pandas as pd

# %%
df_covid = pd.read_csv("datasets/covid_19_data.csv")
df_covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df_covid.shape
# Out:
# (306429, 8)

# %%
df_covid[df_covid['ObservationDate']=='01/22/2020']
# Out:
#     SNo ObservationDate  Province/State  Country/Region      Last Update  \
# 0     1      01/22/2020           Anhui  Mainland China  1/22/2020 17:00
# 1     2      01/22/2020         Beijing  Mainland China  1/22/2020 17:00
# 2     3      01/22/2020       Chongqing  Mainland China  1/22/2020 17:00
# 3     4      01/22/2020          Fujian  Mainland China  1/22/2020 17:00
# 4     5      01/22/2020           Gansu  Mainland China  1/22/2020 17:00
# 5     6      01/22/2020       Guangdong  Mainland China  1/22/2020 17:00
# 6     7      01/22/2020         Guangxi  Mainland China  1/22/2020 17:00
# 7     8      01/22/2020         Guizhou  Mainland China  1/22/2020 17:00
# 8     9      01/22/2020          Hainan  Mainland China  1/22/2020 17:00
# 9    10      01/22/2020           Hebei  Mainland China  1/22/2020 17:00
# 10   11      01/22/2020    Heilongjiang  Mainland China  1/22/2020 17:00
# 11   12      01/22/2020           Henan  Mainland China  1/22/2020 17:00
# ...

# %%
df_china = df_covid[df_covid['Country/Region']=="Mainland China"]
df_china.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df_china.shape
# Out:
# (15758, 8)

# %%
df_covid[df_covid['Country/Region']=='Mauritius']
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 6782      6783      03/18/2020            NaN      Mauritius
# 7072      7073      03/19/2020            NaN      Mauritius
# 7341      7342      03/20/2020            NaN      Mauritius
# 7648      7649      03/21/2020            NaN      Mauritius
# 7832      7833      03/22/2020            NaN      Mauritius
# ...        ...             ...            ...            ...
# 302706  302707      05/25/2021            NaN      Mauritius
# 303471  303472      05/26/2021            NaN      Mauritius
# 304236  304237      05/27/2021            NaN      Mauritius
# 305001  305002      05/28/2021            NaN      Mauritius
# 305766  305767      05/29/2021            NaN      Mauritius
#
#                 Last Update  Confirmed  Deaths  Recovered
# 6782    2020-03-18T19:53:03        3.0     0.0        0.0
# 7072    2020-03-19T02:33:08        3.0     0.0        0.0
# ...
